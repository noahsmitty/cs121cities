# %% [markdown]
# Given a .csv full of URLs for images, lookup archive on wayback
#                  and then download image
#
# Authors: Giovanni Castro, Josh Cheung

# %%
import csv

# !pip install waybackpy
import waybackpy # interface with wayback machine API
import requests # to get image from the web
import shutil # to save it locally

# to parallelize downloads
import multiprocessing
from joblib import Parallel, delayed
from tqdm import tqdm
# Out:
# Collecting waybackpy
#   Downloading https://files.pythonhosted.org/packages/0c/9f/6fa786f18a7a08b319ed1ddf0673f9335b1f50745865c764275e7316edb2/waybackpy-2.4.2-py3-none-any.whl
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from waybackpy) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->waybackpy) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->waybackpy) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->waybackpy) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->waybackpy) (3.0.4)
# Installing collected packages: waybackpy
# Successfully installed waybackpy-2.4.2

# %%
# mount shared drive
from google.colab import drive
drive.mount("/content/drive/")
# Out:
# Mounted at /content/drive/

# %%
#
# define parameters
#
num_images = 1500
### our cities:  london  new_delhi   new_york   san_francisco   tokyo
city = "san_francisco" # exactly as in the csv file name
in_dir = "/content/drive/Shared drives/Team_2_cs121S21/city perception database/imageURLs/"  # must end in "/"
out_dir = f"/content/drive/Shared drives/Team_2_cs121S21/code/data/streets_database/{num_images}/{city}/"
in_filename = f"{city}_URL.csv"

path_to_read = in_dir + in_filename

# %%
#
# read in .csv file filled with URLs
#

with open(path_to_read, newline="") as csvfile:
    reader = csv.reader(csvfile)
    url_list = []
    counter = 0
    for row in reader:
        url_list.append(row[0])
        counter += 1
        if counter >= num_images:
            break
            
print(url_list)
# Out:
# ['http://static.panoramio.com/photos/original/10002316.jpg', 'http://static.panoramio.com/photos/original/10002389.jpg', 'http://static.panoramio.com/photos/original/10011923.jpg', 'http://static.panoramio.com/photos/original/10013438.jpg', 'http://static.panoramio.com/photos/original/10013470.jpg', 'http://static.panoramio.com/photos/original/10014602.jpg', 'http://static.panoramio.com/photos/original/10014624.jpg', 'http://static.panoramio.com/photos/original/10014669.jpg', 'http://static.panoramio.com/photos/original/10014756.jpg', 'http://static.panoramio.com/photos/original/10017149.jpg', 'http://static.panoramio.com/photos/original/10017299.jpg', 'http://static.panoramio.com/photos/original/10018182.jpg', 'http://static.panoramio.com/photos/original/10018188.jpg', 'http://static.panoramio.com/photos/original/10027397.jpg', 'http://static.panoramio.com/photos/original/10027954.jpg', 'http://static.panoramio.com/photos/original/10028044.jpg', 'http://static.panoramio.com/photos/original/10028352.jpg', 'http://static.panoramio.com/photos/original/10033449.jpg', 'http://static.panoramio.com/photos/original/10033465.jpg', 'http://static.panoramio.com/photos/original/10033486.jpg', 'http://static.panoramio.com/photos/original/10034056.jpg', 'http://static.panoramio.com/photos/original/10034115.jpg', 'http://static.panoramio.com/photos/original/10034151.jpg', 'http://static.panoramio.com/photos/original/10034395.jpg', 'http://static.panoramio.com/photos/original/10035714.jpg', 'http://static.panoramio.com/photos/original/10035715.jpg', 'http://static.panoramio.com/photos/original/10040745.jpg', 'http://static.panoramio.com/photos/original/10040851.jpg', 'http://static.panoramio.com/photos/original/10040898.jpg', 'http://static.panoramio.com/photos/original/10042078.jpg', 'http://static.panoramio.com/photos/original/1004339.jpg', 'http://static.panoramio.com/photos/original/10045155.jpg', 'http://static.panoramio.com/photos/original/10048616.jpg', 'http://static.panoramio.com/photos/original/10048659.jpg', 'http://static.panoramio.com/photos/original/10048687.jpg', 'http://static.panoramio.com/photos/original/10049375.jpg', 'http://static.panoramio.com/photos/original/10054718.jpg', 'http://static.panoramio.com/photos/original/10056323.jpg', 'http://static.panoramio.com/photos/original/10057152.jpg', 'http://static.panoramio.com/photos/original/1005874.jpg', 'http://static.panoramio.com/photos/original/10059679.jpg', 'http://static.panoramio.com/photos/original/10062660.jpg', 'http://static.panoramio.com/photos/original/10063441.jpg', 'http://static.panoramio.com/photos/original/10063708.jpg', 'http://static.panoramio.com/photos/original/10067412.jpg', 'http://static.panoramio.com/photos/original/10068691.jpg', 'http://static.panoramio.com/photos/original/10068711.jpg', 'http://static.panoramio.com/photos/original/10068737.jpg', 'http://static.panoramio.com/photos/original/10069111.jpg', 'http://static.panoramio.com/photos/original/10071214.jpg', 'http://static.panoramio.com/photos/original/10071680.jpg', 'http://static.panoramio.com/photos/original/10071709.jpg', 'http://static.panoramio.com/photos/original/10073127.jpg', 'http://static.panoramio.com/photos/original/10073373.jpg', 'http://static.panoramio.com/photos/original/10073398.jpg', 'http://static.panoramio.com/photos/original/10074341.jpg', 'http://static.panoramio.com/photos/original/10074349.jpg', 'http://static.panoramio.com/photos/original/10074356.jpg', 'http://static.panoramio.com/photos/original/10074364.jpg', 'http://static.panoramio.com/photos/original/10074373.jpg', 'http://static.panoramio.com/photos/original/10074386.jpg', 'http://static.panoramio.com/photos/original/10074393.jpg', 'http://static.panoramio.com/photos/original/10074403.jpg', 'http://static.panoramio.com/photos/original/10074872.jpg', 'http://static.panoramio.com/photos/original/10074878.jpg', 'http://static.panoramio.com/photos/original/10075063.jpg', 'http://static.panoramio.com/photos/origi ...

# %%
def get_wayback(url):
  """
  returns the wayback version of the input url
  """
  user_agent = "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/88.0.4324.192 Safari/537.36"
  return str(waybackpy.Url(url, user_agent))

# %%
def download(url, save_dir):
  """
  downloads a single image from <url> and saves it in <save_dir>
  NOTE: <save_dir> must exist before calling this function
  """
  filename = url.split("/")[-1]
  filename = save_dir + filename

  try:
    # Open the url image, set stream to True, this will return the stream content.
    r = requests.get(url, stream = True)

    # Check if the image was retrieved successfully
    if r.status_code == 200:
        # Set decode_content value to True, otherwise the downloaded image file's size will be zero.
        r.raw.decode_content = True

        # Open a local file with wb ( write binary ) permission.
        with open(filename,'wb') as f:
            shutil.copyfileobj(r.raw, f)
        return 0
    else:
      return 1111111
  except:
    print(f"skipped {filename}")
    return 2222222

# %%
num_cores = multiprocessing.cpu_count()
print(num_cores)
# Out:
# 2

# %%
#
# actually get list of wayback urls
#
url_list_tqdm = tqdm(url_list)

wayback_list = Parallel(n_jobs=num_cores)(delayed(get_wayback)(url) for url in url_list_tqdm)
# Out:
# 100%|██████████| 1500/1500 [10:10<00:00,  2.46it/s]

# %%
#
# access, download, and save images to out_dir
#
wayback_list_tqdm = tqdm(wayback_list)

# may take a little while after this block is run for images to appear in drive
save_files = Parallel(n_jobs=num_cores)(delayed(download)(url, out_dir) for url in wayback_list_tqdm)
# Out:
#  70%|██████▉   | 1048/1500 [31:52<12:38,  1.68s/it]

# %%
print(save_files)
